# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %pwd
# Out:
# 'C:\\Users\\jerry\\pylot\\visnn'

# %% [markdown]
# # Original Data (last week)

# %%
df = pd.read_csv("C:\\Users\\jerry\\pylot\\visnn\\vis_data\\vis00.csv")
inputs = df.iloc[:, -4:-1]
outputs = df.iloc[:, -1]

# %%
df
# Out:
#                 TIME  SIMTIME      CAMERA  GROUNDID    LABEL        X  \
# 0      1612812837403     2692  FRONT-eval       333   person  -9.3119
# 1      1612812837403     2692  FRONT-eval       301   person -30.1851
# 2      1612812837404     2692  FRONT-eval       332   person -33.8570
# 3      1612812837405     2692  FRONT-eval       333   person  -9.2389
# 4      1612812837405     2692  FRONT-eval       301   person -30.1744
# ...              ...      ...         ...       ...      ...      ...
# 10035  1612813886086   101442   BACK-eval       286  vehicle   3.9087
# 10036  1612813886086   101442   BACK-eval       357   person   5.6836
# 10037  1612813886431   101492  FRONT-eval       260  vehicle   3.8360
# 10038  1612813886588   101492   BACK-eval       286  vehicle   3.9084
# 10039  1612813886588   101492   BACK-eval       357   person   5.6111
#
#              Y       Z         ERROR
# 0       7.7754  0.8779        6.3452
# 1     -22.4971  0.8782        0.1844
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#n = len(inputs.index)
n = 5000

for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    ax.scatter(x, y, error, marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [markdown]
# ## Original Data with outliers removed

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#n = len(inputs.index)
n = 5000

cnt = 0
for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    if (error > 1000):
        continue
    if (error > 300):
        cnt += 1
    ax.scatter(x, y, error, marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

print(cnt)

plt.show()
# Out:
# 280

# %% [markdown]
# ## Original Data with only FRONT camera

# %%
df = df[df.CAMERA == "FRONT-eval"]
df = df.reset_index(drop=True)
inputs = df.iloc[:, -4:-1]
outputs = df.iloc[:, -1]
df
# Out:
#                TIME  SIMTIME      CAMERA  GROUNDID    LABEL        X        Y  \
# 0     1612812837403     2692  FRONT-eval       333   person  -9.3119   7.7754
# 1     1612812837403     2692  FRONT-eval       301   person -30.1851 -22.4971
# 2     1612812837404     2692  FRONT-eval       332   person -33.8570   7.0722
# 3     1612812837405     2692  FRONT-eval       333   person  -9.2389   7.7839
# 4     1612812837405     2692  FRONT-eval       301   person -30.1744 -22.4304
# ...             ...      ...         ...       ...      ...      ...      ...
# 4913  1612813884430   101292  FRONT-eval       260  vehicle   3.8304  17.1381
# 4914  1612813884972   101342  FRONT-eval       260  vehicle   3.8318  16.6684
# 4915  1612813885591   101392  FRONT-eval       260  vehicle   3.8332  16.1988
# 4916  1612813886055   101442  FRONT-eval       260  vehicle   3.8346  15.7291
# 4917  1612813886431   101492  FRONT-eval       260  vehicle   3.8360  15.2594
#
#            Z         ERROR
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

#n = len(inputs.index)
n = 4000

cnt = 0
for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    if (error > 1000):
        continue
    if (error > 300):
        cnt += 1
    ax.scatter(x, y, error, marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

print(cnt)

plt.show()
# Out:
# 324

# %%
df = df.reset_index(drop=True)
inputs = df
outputs = df.iloc[:, -1]
inputs
# Out:
#                 TIME  SIMTIME      CAMERA  GROUNDID    LABEL        X  \
# 0      1612812837403     2692  FRONT-eval       333   person  -9.3119
# 1      1612812837403     2692  FRONT-eval       301   person -30.1851
# 2      1612812837404     2692  FRONT-eval       332   person -33.8570
# 3      1612812837405     2692  FRONT-eval       333   person  -9.2389
# 4      1612812837405     2692  FRONT-eval       301   person -30.1744
# ...              ...      ...         ...       ...      ...      ...
# 10035  1612813886086   101442   BACK-eval       286  vehicle   3.9087
# 10036  1612813886086   101442   BACK-eval       357   person   5.6836
# 10037  1612813886431   101492  FRONT-eval       260  vehicle   3.8360
# 10038  1612813886588   101492   BACK-eval       286  vehicle   3.9084
# 10039  1612813886588   101492   BACK-eval       357   person   5.6111
#
#              Y       Z         ERROR
# 0       7.7754  0.8779        6.3452
# 1     -22.4971  0.8782        0.1844
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

#n = len(inputs.index)
n = 2000

for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    if (df.iloc[i, :].CAMERA=="FRONT-eval"):
        color = "#e06e5c" if (error > 1000) else "#88c41f"
    else: # back camera
        color = "#a8210c" if (error > 1000) else "#537a0d" # darker version of red/green
        
    ax.scatter(x, y, c=color, marker='o')

ax.set_xlabel('X')
ax.set_ylabel('Y')

plt.show()

# %% [markdown]
# # Front Camera

# %%
df = pd.read_csv("C:\\Users\\jerry\\pylot\\visnn\\vis_data\\front.csv")
inputs = df.iloc[:, -4:-1]
outputs = df.iloc[:, -1]
df
# Out:
#                 TIME  SIMTIME      CAMERA  GROUNDID    LABEL        X  \
# 0      1614794333970     2523  FRONT-eval       280  vehicle -30.2000
# 1      1614794333970     2523  FRONT-eval       345   person -32.6363
# 2      1614794333970     2523  FRONT-eval       273  vehicle -53.0939
# 3      1614794333971     2523  FRONT-eval       345   person -32.6990
# 4      1614794333971     2523  FRONT-eval       280  vehicle -30.2000
# ...              ...      ...         ...       ...      ...      ...
# 16876  1614796231483   291423  FRONT-eval       287  vehicle   7.5114
# 16877  1614796231748   291473  FRONT-eval       284  vehicle -10.3163
# 16878  1614796231748   291473  FRONT-eval       287  vehicle   7.3430
# 16879  1614796232050   291523  FRONT-eval       284  vehicle -10.4354
# 16880  1614796232050   291523  FRONT-eval       287  vehicle   7.1806
#
#              Y       Z         ERROR
# 0       0.0000 -0.0836        3.4411
# 1       7.2874  0.8792       55.4600
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

#n = len(inputs.index)
n = 5000

for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    if (error > 1000):
        ax.scatter(x, y, c="#e06e5c", marker='o')
    else:
        ax.scatter(x, y, c="#88c41f", marker='v')

ax.set_xlabel('X')
ax.set_ylabel('Y')

plt.show()

# %% [markdown]
# # Front Camera (all ground obstacles)

# %%
df = pd.read_csv("C:\\Users\\jerry\\pylot\\visnn\\vis_data\\frontall.csv")
inputs = df.iloc[:, -4:-1]
outputs = df.iloc[:, -1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

#n = len(inputs.index)
n = 5000

for i in range(n):
    x = inputs.iloc[i, :].X
    y = inputs.iloc[i, :].Y
    error = outputs[i]
    if (error > 1000):
        ax.scatter(x, y, c="#e06e5c", marker='o')
    else:
        ax.scatter(x, y, c="#88c41f", marker='v')

ax.set_xlabel('X')
ax.set_ylabel('Y')

plt.show()
